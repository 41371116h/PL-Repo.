# %% [markdown]
# <a href="https://colab.research.google.com/github/41371116h/PL-Repo./blob/main/%E3%80%8CHW3%E5%BE%85%E8%BE%A6%E6%B8%85%E5%96%AE%E8%88%87%E7%95%AA%E8%8C%84%E9%90%98%E7%B4%80%E9%8C%84(AI_Plan).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HW3待辦清單與番茄鐘紀錄(AI_Plan)（作業三）
# - 目標：可以把平常要做的任務新增到任務清單，再到任務管理分頁可以選擇刪除、標記為完成或是更新狀態，AI也會給出早中晚排程建議，以及加入CSV匯入及匯出檔案功能(可以直接聞到本機)，也可以看到用視覺化圖表呈現完成率狀況
# - AI 點子（可選）：早中晚排程建議
# - Gradio分頁:📋 任務清單、✏️ 任務管理⏱️、番茄鐘🤖、AI Plan📤 、匯入、📊 視覺化統計
# - Sheet 欄位：id,任務名稱,優先級,預估時間,到期日,狀態
# - GoogleSheet: https://docs.google.com/spreadsheets/d/1GScHTHISiioV89XO5twgGl-IpaYG-0nMwhLRTizSpNI/edit?pli=1&gid=0#gid=0

# %%
# ============================================
# ✅ 任務清單管理系統（Google Sheets + 番茄鐘 + AI Plan + 匯出/匯入 + 統計 實作）
# ============================================
import gradio as gr
import pandas as pd
import datetime
import gspread
from google.colab import auth
from google.auth import default
import time
import random
import google.generativeai as genai
import json # 解析 AI 輸出時可能用到
from io import StringIO, BytesIO # 用於解析 Markdown 表格及處理檔案
import re # 用於進一步清理 Markdown 輸入
import os # 用於檔案操作
import tempfile # 用於生成可下載的暫存檔案
import matplotlib.pyplot as plt

# ====== Google Sheets 設定 ======
SHEET_URL = "https://docs.google.com/spreadsheets/d/1GScHTHISiioV89XO5twgGl-IpaYG-0nMwhLRTizSpNI/edit"
TASKS_SHEET = "工作表2" # 假設這是儲存任務清單的分頁
PLAN_SHEET = "番茄鐘(Gemini PLAN)" # 儲存 AI 計劃的分頁

# ====== Google Sheets 認證與初始化 ======
task_ws = None
plan_ws = None
try:
    auth.authenticate_user()
    creds, _ = default()
    gc = gspread.authorize(creds)
    gsheets = gc.open_by_url(SHEET_URL)

    try:
        task_ws = gsheets.worksheet(TASKS_SHEET)
    except gspread.WorksheetNotFound:
        # 建立任務清單分頁
        task_ws = gsheets.add_worksheet(title=TASKS_SHEET, rows="200", cols="6")
        task_ws.append_row(["id", "任務名稱", "優先級", "預估時間", "到期日", "狀態"], value_input_option="USER_ENTERED")

    try:
        plan_ws = gsheets.worksheet(PLAN_SHEET)
    except gspread.WorksheetNotFound:
        # 建立 AI Plan 分頁
        plan_ws = gsheets.add_worksheet(title=PLAN_SHEET, rows="50", cols="4")
        plan_ws.append_row(["時間段", "任務名稱", "建議", "備註"], value_input_option="USER_ENTERED")

    print("✅ 已成功連線 Google Sheets")
except Exception as e:
    print(f"❌ Google Sheets 連線失敗: {e}")

# ====== Gemini API 設定 ======
model = None
try:
    # !!! 請替換為您真實的 API Key !!!
    GEMINI_API_KEY = "AIzaSyAWyvSMGkAgiTMSdE8TEId8IFDw0OD46io"
    genai.configure(api_key=GEMINI_API_KEY)
    # 使用 Flash 模型，它速度快、成本低，適合規劃任務
    model = genai.GenerativeModel("gemini-2.5-flash")
    print("✅ Gemini API 配置成功。")
except Exception as e:
    print(f"❌ Gemini API 配置失敗: {e}")

# ====== 工具函式 ======
def read_tasks():
    if not task_ws:
        return pd.DataFrame(columns=["id", "任務名稱", "優先級", "預估時間", "到期日", "狀態"])
    try:
        data = task_ws.get_all_values()
        if len(data) <= 1:
            return pd.DataFrame(columns=data[0] if data else ["id", "任務名稱", "優先級", "預估時間", "到期日", "狀態"])
        df = pd.DataFrame(data[1:], columns=data[0])
        return df
    except Exception as e:
        print(f"讀取任務時發生錯誤: {e}")
        return pd.DataFrame(columns=["id", "任務名稱", "優先級", "預估時間", "到期日", "狀態"])

def write_tasks(df):
    if not task_ws:
        return
    cols_to_write = ["id", "任務名稱", "優先級", "預估時間", "到期日", "狀態"]
    if all(col in df.columns for col in cols_to_write):
        df = df[cols_to_write]

    task_ws.clear()
    task_ws.append_row(list(df.columns))
    for _, row in df.iterrows():
        # 確保所有值都是字串，避免 Sheets 格式錯誤
        task_ws.append_row([str(x) for x in row.tolist()], value_input_option="USER_ENTERED")

def new_id():
    return datetime.datetime.now().strftime("%Y%m%d%H%M%S")

def refresh_all():
    df = read_tasks()
    task_choices = df["任務名稱"].tolist() if not df.empty else []
    return df, gr.update(value=df), gr.update(choices=task_choices), gr.update(choices=task_choices)

# ====== 任務操作功能 ======
def add_task(name, priority, est_min, due_date):
    if not task_ws:
        return "❌ Sheets 未連線", read_tasks()
    try:
        df = read_tasks()
        new_row = {
            "id": new_id(),
            "任務名稱": name,
            "優先級": priority,
            "預估時間": str(est_min),
            "到期日": due_date,
            "狀態": "todo"
        }
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)
        write_tasks(df)
        return f"✅ 已新增任務：{name}", df
    except Exception as e:
        return f"❌ 新增任務錯誤：{e}", read_tasks()

def update_status(task_name, new_status):
    if not task_ws:
        return "❌ Sheets 未連線", read_tasks()
    df = read_tasks()
    if task_name not in df["任務名稱"].values:
        return f"❌ 任務不存在：{task_name}", df
    df.loc[df["任務名稱"] == task_name, "狀態"] = new_status
    write_tasks(df)
    df_new = read_tasks()
    return f"✏️ 任務「{task_name}」狀態更新為 {new_status}", df_new

def delete_task(task_name):
    if not task_ws:
        return "❌ Sheets 未連線", read_tasks()
    df = read_tasks()
    if task_name not in df["任務名稱"].values:
        return f"❌ 任務不存在：{task_name}", df
    df = df[df["任務名稱"] != task_name]
    write_tasks(df)
    df_new = read_tasks()
    return f"🗑️ 已刪除任務「{task_name}」", df_new

def mark_done(task_name):
    return update_status(task_name, "done")

def sync_tasks():
    df_latest = read_tasks()
    task_choices = df_latest["任務名稱"].tolist() if not df_latest.empty else []
    return df_latest, gr.update(choices=task_choices), gr.update(choices=task_choices)

# ====== 番茄鐘 ======
timer_state = {"running": False, "paused": False, "start_time": None, "remaining": 0, "duration": 0}

def timer_generator(task_name, mode):
    timer_state["duration"] = 25*60 if mode=="work" else 5*60
    timer_state["remaining"] = timer_state["duration"]
    timer_state["running"] = True
    timer_state["paused"] = False
    timer_state["start_time"] = time.time()

    while timer_state["running"] and timer_state["remaining"] > 0:
        if timer_state["paused"]:
            timer_state["start_time"] = time.time() - (timer_state["duration"] - timer_state["remaining"])
            time.sleep(0.2)
            continue
        elapsed = time.time() - timer_state["start_time"]
        timer_state["remaining"] = timer_state["duration"] - elapsed
        if timer_state["remaining"] <= 0:
            timer_state["remaining"] = 0
            timer_state["running"] = False
        mins, secs = divmod(int(timer_state["remaining"]), 60)
        yield f"<h1 style='font-size:60px; color:#FF4500'>{task_name} ⏱ {mins:02d}:{secs:02d}</h1>"
        time.sleep(1)
    yield f"<h1 style='font-size:50px; color:green'>⏰ {task_name} 時間到！</h1>"

def pause_timer():
    timer_state["paused"] = not timer_state["paused"]
    status = "⏸ 暫停中" if timer_state["paused"] else "▶️ 繼續計時"
    return f"<h2>{status}</h2>"

def reset_timer(task_name, mode):
    timer_state["duration"] = 25*60 if mode=="work" else 5*60
    timer_state["remaining"] = timer_state["duration"]
    timer_state["running"] = False
    timer_state["paused"] = False
    mins, secs = divmod(int(timer_state["remaining"]), 60)
    return f"<h1 style='font-size:60px; color:#1E90FF'>{task_name} ⏱ {mins:02d}:{secs:02d}</h1>"

# ====== AI Plan 功能（已修正無空白行） ======
def generate_plan_with_ai(tasks_df):
    empty_df = pd.DataFrame(columns=["時間段","任務名稱","建議","備註"])
    if not model:
        return empty_df, "❌ Gemini API 未成功配置，無法生成計畫。"
    if not task_ws or not plan_ws:
        return empty_df, "❌ Google Sheets 未連線，無法讀取資料或寫入計畫。"
    active_tasks = tasks_df[tasks_df["狀態"].isin(["todo", "in-progress"])]
    if active_tasks.empty:
        return empty_df, "⚠️ 目前沒有待辦或進行中的任務，無需生成計畫。"
    tasks_for_ai = active_tasks[["任務名稱", "優先級", "預估時間", "到期日"]].copy()
    task_list = tasks_for_ai.to_markdown(index=False)

    prompt = f"""
    你是一個專業的任務規劃助理。請根據以下待辦任務清單，為使用者安排一天的「番茄鐘（Pomodoro）」計畫。
    請將任務分配到三個時間段：'Morning' (上午, 高效時段), 'Afternoon' (下午, 中等時段), 'Evening' (晚上, 彈性時段)。

    任務清單如下：
    {task_list}

    規則：
    1. 你必須以 **Markdown Table** 的格式直接輸出結果，**且除了表格內容外，不要包含任何額外的文字、標題或解釋。**
    2. 表格的欄位必須且只能是：時間段, 任務名稱, 建議, 備註。
    3. 確保所有待辦任務（除了明顯不適合今天完成的）都至少被分配一次。
    4. '建議' 欄位請給出一個簡短的執行策略（例如：優先處理高優任務、專注完成大塊工作等）。
    5. '時間段' 必須是 'Morning', 'Afternoon', 或 'Evening' 之一。

    請直接輸出 Markdown Table：
    """

    try:
        response = model.generate_content(prompt, request_options={"timeout": 60})
        plan_text = response.text.strip()

        # 🎯 核心優化：更精確地解析 Markdown 表格，避免產生空行或雜訊。
        lines = [ln.strip() for ln in plan_text.splitlines() if ln.strip()]
        # 移除 Markdown 分隔線 (e.g., |---|---|)
        lines = [ln for ln in lines if not re.match(r"^\s*\|?\s*-{1,}\s*\|", ln)]

        if not lines or len(lines)<2:
            raise ValueError(f"AI 輸出無法解析: {plan_text}")

        # 解析表格（從原始分隔確保首尾 | 都去除）
        parsed = []
        for ln in lines:
            # 移除行首尾的 |
            l_clean = ln.strip("|")
            parts = [p.strip() for p in l_clean.split("|")]
            # 確保 parts 不為空 (例如避免純 | 的行)
            if any(parts):
                 parsed.append(parts)

        # 轉為 DataFrame
        df_plan = pd.DataFrame(parsed)
        # 第一列為欄名
        df_plan.columns = df_plan.iloc[0]
        df_plan = df_plan[1:].reset_index(drop=True)

        # 清理欄位
        df_plan.columns = df_plan.columns.str.strip()
        df_plan = df_plan.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

        required_cols = ["時間段", "任務名稱", "建議", "備註"]
        if not all(col in df_plan.columns for col in required_cols):
             raise ValueError(f"解析後的欄位名稱不符預期: {df_plan.columns.tolist()}")

        df_plan = df_plan[required_cols]
        # 再次過濾任務名稱為空（或空白）的行
        df_plan = df_plan[df_plan["任務名稱"].astype(str).str.strip().ne("")]

        # 6. 寫入 Google Sheets
        plan_ws.clear()
        plan_ws.append_row(list(df_plan.columns))
        for _, row in df_plan.iterrows():
            plan_ws.append_row([str(x) for x in row.tolist()], value_input_option="USER_ENTERED")

        return df_plan, "✅ AI 計畫已成功生成，並同步到 Google Sheets！"

    except Exception as e:
        error_msg = f"❌ AI 計畫生成或解析錯誤：{e}"
        return empty_df, error_msg

# Gradio 專用的 Wrapper 函式，用於處理多重輸出
def generate_plan_wrapper():
    df, msg = generate_plan_with_ai(read_tasks())
    return df, gr.Markdown(value=msg)


# ===== 匯出 / 匯入 功能函式 (從您提供的程式碼複製) =====
def export_tasks_csv():
    df = read_tasks()
    if df.empty:
        # 建立空檔案
        tmp = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
        tmp.write("".encode("utf-8"))
        tmp.close()
        return tmp.name
    tmp = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
    df.to_csv(tmp.name, index=False, encoding="utf-8-sig")
    tmp.close()
    return tmp.name

def export_tasks_json():
    df = read_tasks()
    tmp = tempfile.NamedTemporaryFile(delete=False, suffix=".json")
    with open(tmp.name, "w", encoding="utf-8") as f:
        f.write(df.to_json(orient="records", force_ascii=False, indent=2))
    tmp.close()
    return tmp.name

def export_plan_csv():
    if not plan_ws:
        tmp = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
        tmp.close()
        return tmp.name
    plan_data = plan_ws.get_all_values()
    if len(plan_data) <= 1:
        tmp = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
        tmp.close()
        return tmp.name
    df = pd.DataFrame(plan_data[1:], columns=plan_data[0])
    tmp = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
    df.to_csv(tmp.name, index=False, encoding="utf-8-sig")
    tmp.close()
    return tmp.name

def import_tasks(file):
    if file is None:
        return "⚠️ 請先選擇要匯入的檔案", read_tasks()
    try:
        path = file.name # Gradio file object has .name attribute

        # 判斷副檔名
        _, ext = os.path.splitext(path)
        ext = ext.lower()
        if ext == ".csv":
            df = pd.read_csv(path, dtype=str)
        elif ext == ".json":
            df = pd.read_json(path, dtype=str)
        else:
            # 嘗試讀取為 JSON，失敗再讀 CSV (處理無副檔名情況)
            try:
                df = pd.read_json(path, dtype=str)
            except Exception:
                df = pd.read_csv(path, dtype=str)

        # 檢查欄位並補齊/清理
        expected_cols = ["id", "任務名稱", "優先級", "預估時間", "到期日", "狀態"]
        if not all(col in df.columns for col in ["任務名稱"]):
            return "❌ 匯入失敗：檔案中找不到 '任務名稱' 欄位。", read_tasks()

        if "id" not in df.columns:
            df["id"] = df.apply(lambda _: new_id(), axis=1)

        for col in expected_cols:
            if col not in df.columns:
                df[col] = ""

        df = df[expected_cols]

        # 寫回 Google Sheets
        write_tasks(df)
        df_new = read_tasks()
        return f"✅ 成功匯入 {len(df)} 筆任務。", df_new
    except Exception as e:
        return f"❌ 匯入失敗：{e}", read_tasks()

# ====== 統計視覺化功能 (從您提供的程式碼複製) =====
def generate_stats():
    df = read_tasks()

    # 狀態分布圖
    if df.empty:
        fig = plt.figure()
        plt.text(0.5, 0.5, "No Data", ha='center', va='center')
        plt.axis('off')
    else:
        status_counts = df["狀態"].value_counts()
        fig = plt.figure(figsize=(4,4))
        plt.pie(status_counts.values, labels=status_counts.index, autopct='%1.1f%%')
        plt.title("任務狀態分布")

    # 今日 AI 計畫與完成情況
    plan_df = pd.DataFrame(columns=["時間段","任務名稱","建議","備註"])
    try:
        if plan_ws:
            p = plan_ws.get_all_values()
            if len(p) > 1:
                plan_df = pd.DataFrame(p[1:], columns=p[0])
    except Exception:
        plan_df = pd.DataFrame(columns=["時間段","任務名稱","建議","備註"])

    if not plan_df.empty:
        # 加入狀態欄位（從 tasks df 匹配）
        merged = plan_df.merge(df[["任務名稱","狀態"]], on="任務名稱", how="left")
        if "狀態" not in merged.columns:
            merged["狀態"] = ""
        merged = merged[["時間段","任務名稱","狀態"]]
    else:
        merged = pd.DataFrame(columns=["時間段","任務名稱","狀態"])

    return fig, merged


# ====== Gradio 介面 ======
with gr.Blocks(title="任務清單管理系統") as demo:
    gr.Markdown("## ✅ 任務清單管理系統（Google Sheets 即時同步 + 番茄鐘 + AI Plan）")

    initial_df = read_tasks()
    initial_choices = initial_df["任務名稱"].tolist() if not initial_df.empty else []

    sel_task_mgr = gr.State(value=initial_choices)
    sel_task_timer_state = gr.State(value=initial_choices)

    with gr.Tabs():
        # --------------------------
        # 任務清單
        # --------------------------
        with gr.Tab("📋 任務清單"):
            with gr.Row():
                task_name_input = gr.Textbox(label="任務名稱")
                priority_input = gr.Dropdown(["H","M","L"], value="M", label="優先級")
            with gr.Row():
                est_min_input = gr.Number(label="預估時間（分鐘）", value=25)
                due_date_input = gr.Textbox(label="到期日 (YYYY-MM-DD，可留空)")
            btn_add = gr.Button("➕ 新增任務")
            msg_add = gr.Markdown()
            btn_refresh = gr.Button("🔄 重新整理清單")
            grid_tasks = gr.Dataframe(value=initial_df, label="📋 任務清單", interactive=False)

        # --------------------------
        # 任務管理
        # --------------------------
        with gr.Tab("✏️ 任務管理"):
            sel_task = gr.Dropdown(choices=initial_choices, label="選擇任務")
            new_status = gr.Dropdown(["todo","in-progress","done"], label="更新狀態")
            btn_update = gr.Button("✏️ 更新狀態")
            btn_delete = gr.Button("🗑️ 刪除任務")
            btn_done = gr.Button("✅ 標記完成")
            btn_sync_select = gr.Button("🔄 同步選擇任務")
            msg_action = gr.Markdown()
            grid_tasks2 = gr.Dataframe(value=initial_df, label="目前任務", interactive=False)

        # --------------------------
        # 番茄鐘
        # --------------------------
        with gr.Tab("⏱️ 番茄鐘"):
            sel_task_timer = gr.Dropdown(choices=initial_choices, label="選擇任務計時")
            mode = gr.Radio(choices=["work","break"], value="work", label="模式選擇")
            btn_start_timer = gr.Button("▶️ Start")
            btn_pause_timer = gr.Button("⏸️ 暫停 / 繼續")
            btn_reset_timer = gr.Button("🔄 重置")
            timer_output = gr.HTML(label="倒數計時", value=f"<h1 style='font-size:60px; color:#1E90FF'>選擇任務 ⏱ 25:00</h1>")

        # --------------------------
        # AI Plan
        # --------------------------
        with gr.Tab("🤖 AI Plan"):
            btn_generate_plan = gr.Button("🧠 生成今日計畫 (Gemini)")
            msg_plan = gr.Markdown()
            plan_output = gr.Dataframe(value=pd.DataFrame(columns=["時間段","任務名稱","建議","備註"]), label="AI 行動計畫")

        # --------------------------
        # 匯出 / 匯入紀錄
        # --------------------------
        with gr.Tab("💾 匯出 / 匯入紀錄"):
            gr.Markdown("### 📤 匯出任務與 AI 計畫")
            with gr.Row():
                btn_export_csv = gr.Button("📄 匯出任務清單 (CSV)")
                btn_export_json = gr.Button("🧾 匯出任務清單 (JSON)")
                btn_export_plan = gr.Button("📘 匯出 AI 計畫 (CSV)")
            file_output = gr.File(label="下載檔案")
            gr.Markdown("### 📥 匯入任務清單 (CSV / JSON)")
            file_upload = gr.File(label="上傳 CSV 或 JSON")
            btn_import = gr.Button("🔄 匯入任務清單")
            msg_import = gr.Markdown()

        # --------------------------
        # 視覺化統計（進階）
        # --------------------------
        with gr.Tab("📊 統計"):
            stats_plot = gr.Plot(label="任務狀態分布")
            stats_table = gr.Dataframe(value=pd.DataFrame(columns=["時間段","任務名稱","狀態"]), label="今日 AI 計畫完成情況")
            # 依您的要求，保留這個按鈕
            stats_btn = gr.Button("🔍 重新產生統計")

    # ====== 事件綁定 ======
    btn_add.click(add_task,
                  inputs=[task_name_input, priority_input, est_min_input, due_date_input],
                  outputs=[msg_add, grid_tasks]) \
           .then(sync_tasks, None, [grid_tasks2, sel_task, sel_task_timer])

    btn_refresh.click(lambda: read_tasks(), outputs=[grid_tasks])

    btn_update.click(update_status, inputs=[sel_task, new_status], outputs=[msg_action, grid_tasks2]) \
           .then(sync_tasks, None, [grid_tasks, sel_task, sel_task_timer])

    btn_delete.click(delete_task, inputs=[sel_task], outputs=[msg_action, grid_tasks2]) \
           .then(sync_tasks, None, [grid_tasks, sel_task, sel_task_timer])

    btn_done.click(mark_done, inputs=[sel_task], outputs=[msg_action, grid_tasks2]) \
           .then(sync_tasks, None, [grid_tasks, sel_task, sel_task_timer])

    btn_sync_select.click(sync_tasks, outputs=[grid_tasks2, sel_task, sel_task_timer])

    btn_start_timer.click(timer_generator, inputs=[sel_task_timer, mode], outputs=[timer_output])
    btn_pause_timer.click(pause_timer, outputs=[timer_output])
    btn_reset_timer.click(reset_timer, inputs=[sel_task_timer, mode], outputs=[timer_output])

    btn_generate_plan.click(generate_plan_wrapper, inputs=None, outputs=[plan_output, msg_plan])

    # 匯出（回傳檔案路徑字串給 gr.File）
    btn_export_csv.click(export_tasks_csv, outputs=[file_output])
    btn_export_json.click(export_tasks_json, outputs=[file_output])
    btn_export_plan.click(export_plan_csv, outputs=[file_output])

    # 匯入
    btn_import.click(import_tasks, inputs=[file_upload], outputs=[msg_import, grid_tasks]) \
              .then(sync_tasks, None, [grid_tasks2, sel_task, sel_task_timer])

    # 統計產生
    def _gen_stats_and_table():
        fig, df = generate_stats()
        return fig, df
    # 綁定統計按鈕
    stats_btn.click(_gen_stats_and_table, outputs=[stats_plot, stats_table])

    # 初始加載統計圖表 (只顯示一次)
    demo.load(_gen_stats_and_table, outputs=[stats_plot, stats_table])

# ====== 啟動 App ======
if __name__ == "__main__":
    demo.launch(debug=True, share=True)
# Out:
# ✅ 已成功連線 Google Sheets
# ✅ Gemini API 配置成功。
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://3d92cf3fbd458b3739.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3d92cf3fbd458b3739.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 20219 (\N{CJK UNIFIED IDEOGRAPH-4EFB}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 29376 (\N{CJK UNIFIED IDEOGRAPH-72C0}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 24907 (\N{CJK UNIFIED IDEOGRAPH-614B}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 20219 (\N{CJK UNIFIED IDEOGRAPH-4EFB}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 29376 (\N{CJK UNIFIED IDEOGRAPH-72C0}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 24907 (\N{CJK UNIFIED IDEOGRAPH-614B}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 20219 (\N{CJK UNIFIED IDEOGRAPH-4EFB}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 29376 (\N{CJK UNIFIED IDEOGRAPH-72C0}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 24907 (\N{CJK UNIFIED IDEOGRAPH-614B}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 20219 (\N{CJK UNIFIED IDEOGRAPH-4EFB}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 29376 (\N{CJK UNIFIED IDEOGRAPH-72C0}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 24907 (\N{CJK UNIFIED IDEOGRAPH-614B}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# /usr/local/lib/python3.12/dist-packages/gradio/processing_utils.py:81: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from font(s) DejaVu Sans.
#   plt.savefig(output_bytes, format=fmt)
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://3d92cf3fbd458b3739.gradio.live
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 20219 (\N{CJK UNIFIED IDEOGRAPH-4EFB}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 21209 (\N{CJK UNIFIED IDEOGRAPH-52D9}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 29376 (\N{CJK UNIFIED IDEOGRAPH-72C0}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 24907 (\N{CJK UNIFIED IDEOGRAPH-614B}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
